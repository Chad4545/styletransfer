# %%
import torch
from PIL import Image
import numpy as np
'''
Image module의 보간법 3개

NONE = 0
NEAREST = 0
ANTIALIAS = 1
LINEAR = BILINEAR = 2
CUBIC = BICUBIC = 3
'''
# Out:
# '\nImage module의 보간법 3개\n\nNONE = 0\nNEAREST = 0\nANTIALIAS = 1\nLINEAR = BILINEAR = 2\nCUBIC = BICUBIC = 3\n'

# %%
img = Image.open('11.jpg')
img1 = img.resize((150,200),Image.ANTIALIAS)
img2 = img.resize((150,200),Image.NEAREST)
img3 = img.resize((150,200),Image.BILINEAR)
img4 = img.resize((150,200),Image.BICUBIC)

# %%
f, axarr = plt.subplots(2,2,figsize=(10,10))
axarr[0][0].imshow(img1)
axarr[0][1].imshow(img2)
axarr[1][0].imshow(img3)
axarr[1][1].imshow(img4)
plt.show()

# %%
batch1 = batch1.div_(255.0)
batch1
# Out:
# tensor([[[[ 1.1557e-03,  4.0864e-03, -3.0913e-03,  ..., -3.9380e-03,
#             4.1646e-04,  1.3222e-03],
#           [-1.8071e-03, -4.4160e-03,  1.2589e-03,  ..., -3.6278e-03,
#            -5.8847e-04,  4.2977e-03],
#           [ 4.2522e-03, -1.5497e-03,  1.1409e-03,  ..., -1.1298e-03,
#            -2.8833e-03,  6.4747e-04],
#           ...,
#           [-2.2405e-03, -6.4974e-03, -8.6690e-04,  ..., -8.5933e-03,
#             3.5484e-03, -5.3930e-03],
#           [ 3.1321e-03,  1.9759e-03, -7.0283e-03,  ...,  6.9307e-03,
#            -9.6889e-04, -2.8200e-03],
#           [-1.7046e-03, -4.2165e-03,  5.1487e-03,  ..., -3.3740e-03,
#             2.0920e-03,  6.9657e-03]],
#
#          [[-3.3946e-03,  3.1055e-03, -1.8659e-03,  ...,  3.2391e-03,
#            -1.3636e-03, -6.0465e-04],
#           [ 5.1736e-03, -4.0350e-03, -1.8007e-03,  ..., -2.7724e-03,
#            -3.9897e-03,  3.9768e-03],
#           [-2.7495e-03,  3.9196e-03,  6.7721e-03,  ...,  2.8678e-03,
# ...

# %%
(batch1 - mean) / std
# Out:
# tensor([[[[-2.1129, -2.1001, -2.1314,  ..., -2.1351, -2.1161, -2.1121],
#           [-2.1258, -2.1372, -2.1124,  ..., -2.1337, -2.1205, -2.0991],
#           [-2.0993, -2.1247, -2.1129,  ..., -2.1228, -2.1305, -2.1151],
#           ...,
#           [-2.1277, -2.1463, -2.1217,  ..., -2.1554, -2.1024, -2.1415],
#           [-2.1042, -2.1093, -2.1486,  ..., -2.0876, -2.1221, -2.1302],
#           [-2.1253, -2.1363, -2.0954,  ..., -2.1326, -2.1088, -2.0875]],
#
#          [[-2.0509, -2.0219, -2.0440,  ..., -2.0213, -2.0418, -2.0384],
#           [-2.0126, -2.0537, -2.0438,  ..., -2.0481, -2.0535, -2.0180],
#           [-2.0480, -2.0182, -2.0055,  ..., -2.0229, -2.0377, -2.0501],
#           ...,
#           [-2.0242, -2.0452, -2.0077,  ..., -2.0229, -2.0346, -2.0123],
#           [-2.0204, -2.0376, -2.0526,  ..., -2.0612, -2.0155, -2.0215],
#           [-2.0212, -2.0447, -2.0565,  ..., -2.0270, -2.0390, -2.0175]],
#
# ...
